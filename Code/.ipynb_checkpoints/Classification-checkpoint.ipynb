# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
#import librarires
# import kerastuner as kt #hypertuning for Tensorflow 2
from tensorflow import keras
import tensorflow as tf
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameter as hp
from keras.layers import Dense,Dropout,Activation,Add,MaxPooling2D,Conv2D,Flatten
from keras.models import Sequential 
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from keras.applications import VGG19
from keras import layers
from keras.preprocessing import image
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-12c3f8756bbd> in <module>
#       1 #import librarires
#       2 # import kerastuner as kt #hypertuning for Tensorflow 2
# ----> 3 from tensorflow import keras
#       4 import tensorflow as tf
#       5 from kerastuner.tuners import RandomSearch
#
# /media/susanchen/6TB_HDD/cys_materials/miniconda3/envs/project2_class_env/lib/python3.6/site-packages/tensorflow/keras/__init__.py in <module>
#      17 from . import callbacks
#      18 from . import constraints
# ---> 19 from . import datasets
#      20 from . import estimator
#      21 from . import experimental
#
# /media/susanchen/6TB_HDD/cys_materials/miniconda3/envs/project2_class_env/lib/python3.6/site-packages/tensorflow/keras/datasets/__init__.py in <module>
#      12 from . import cifar100
#      13 from . import fashion_mnist
# ---> 14 from . import imdb
#      15 from . import mnist
#      16 from . import reuters
#
# /media/susanchen/6TB_HDD/cys_materials/miniconda3/envs/project2_class_env/lib/python3.6/site-packages/tensorflow/keras/datasets/imdb/__init__.py in <module>
#       9 import sys as _sys
#      10
# ---> 11 from tensorflow.python.keras.datasets.imdb import get_word_index
#      12 from tensorflow.python.keras.datasets.imdb import load_data
#      13
#
# /media/susanchen/6TB_HDD/cys_materials/miniconda3/envs/project2_class_env/lib/python3.6/site-packages/tensorflow/python/keras/datasets/imdb.py in <module>
#      23 import numpy as np
#      24
# ---> 25 from tensorflow.python.keras.preprocessing.sequence import _remove_long_seq
#      26 from tensorflow.python.keras.utils.data_utils import get_file
#      27 from tensorflow.python.platform import tf_logging as logging
#
# /media/susanchen/6TB_HDD/cys_materials/miniconda3/envs/project2_class_env/lib/python3.6/site-packages/tensorflow/python/keras/preprocessing/__init__.py in <module>
#      21 # TODO(mihaimaruseac): remove the import of keras_preprocessing and injecting
#      22 # once we update to latest version of keras_preprocessing
# ---> 23 import keras_preprocessing
#      24
#      25 from tensorflow.python.keras import backend
#
# ModuleNotFoundError: No module named 'keras_preprocessing'

# %%
#load data
train_data = defect_tree = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/classification_data/train',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset="training",
    interpolation="bilinear",
    follow_links=False,
)
test_data = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/classification_data/train',
    labels="inferred",
    label_mode="int",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset="validation",
    interpolation="bilinear",
    follow_links=False,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ec36da04efe5> in <module>
#       2
#       3
# ----> 4 train_data = defect_tree = tf.keras.preprocessing.image_dataset_from_directory(
#       5     '../Data/classification_data/train',
#       6     labels="inferred",
#
# NameError: name 'tf' is not defined

# %%
#classes 
class_names =  ["COVID-19","NORMAL","Viral Pneumonia"]
for i in range(len(class_names)):
    print(class_names[i] ," " , i)
# Out:
# COVID-19   0
# NORMAL   1
# Viral Pneumonia   2

# %%
#visualize data
image_path = "../input/covid19-radiography-database/COVID-19 Radiography Database/Viral Pneumonia/Viral Pneumonia (1024).png"
new_img = image.load_img(image_path, target_size=(244, 244))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
print("Viral Pneumonia")
plt.imshow(new_img)
# Out:
# Viral Pneumonia

# %%
#visualize data
image_path = "../input/covid19-radiography-database/COVID-19 Radiography Database/NORMAL/NORMAL (1013).png"
new_img = image.load_img(image_path, target_size=(244, 244))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
print("NORMAL")
plt.imshow(new_img)
# Out:
# NORMAL

# %%
#visualize data
image_path = "../input/covid19-radiography-database/COVID-19 Radiography Database/COVID-19/COVID-19 (123).png"
new_img = image.load_img(image_path, target_size=(244, 244))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
print("COVID-19")
plt.imshow(new_img)
# Out:
# COVID-19

# %%
#visulaize data
fig, ax = plt.subplots()
ax.bar("COVID-19",219,color="r",label="covid19")
ax.bar("NORMAL",1341,color="b",label="normal")
ax.bar("Viral Pneumonia",1345,color="g",label="viral pneumonia")
ax.legend()

# %%
## Defining Cnn
model = tf.keras.models.Sequential([
  layers.BatchNormalization(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.3),
  layers.Conv2D(128, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dropout(0.15),
  layers.Dense(3, activation= 'softmax')
])

# %%
#to avoid overfitting
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)

# %%
#compile model
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
## fit model
history=model.fit(train_data,validation_data= test_data,batch_size=32,epochs = 20,callbacks=[early])
# Out:
# Epoch 1/20
# 73/73 [==============================] - 61s 831ms/step - loss: 1.6382 - accuracy: 0.7689 - val_loss: 1.7413 - val_accuracy: 0.5129
# Epoch 2/20
# 73/73 [==============================] - 48s 655ms/step - loss: 0.2247 - accuracy: 0.9204 - val_loss: 0.7108 - val_accuracy: 0.7384
# Epoch 3/20
# 73/73 [==============================] - 47s 650ms/step - loss: 0.2075 - accuracy: 0.9247 - val_loss: 0.2062 - val_accuracy: 0.9191
# Epoch 4/20
# 73/73 [==============================] - 47s 643ms/step - loss: 0.1204 - accuracy: 0.9570 - val_loss: 0.1940 - val_accuracy: 0.9243
# Epoch 5/20
# 73/73 [==============================] - 46s 627ms/step - loss: 0.1299 - accuracy: 0.9544 - val_loss: 0.1566 - val_accuracy: 0.9466
# Epoch 6/20
# 73/73 [==============================] - 45s 621ms/step - loss: 0.0840 - accuracy: 0.9694 - val_loss: 0.1662 - val_accuracy: 0.9380
# Epoch 7/20
# 73/73 [==============================] - 46s 633ms/step - loss: 0.0722 - accuracy: 0.9742 - val_loss: 0.1554 - val_accuracy: 0.9518
# Epoch 8/20
# 73/73 [==============================] - 46s 626ms/step - loss: 0.0552 - accuracy: 0.9832 - val_loss: 0.1523 - val_accuracy: 0.9432
# Epoch 9/20
# 73/73 [==============================] - 45s 618ms/step - loss: 0.0372 - accuracy: 0.9880 - val_loss: 0.1679 - val_accuracy: 0.9449
# Epoch 10/20
# 73/73 [==============================] - 46s 624ms/step - loss: 0.0341 - accuracy: 0.9875 - val_loss: 0.1631 - val_accuracy: 0.9484
# Epoch 11/20
# 73/73 [==============================] - 45s 611ms/step - loss: 0.0237 - accuracy: 0.9940 - val_loss: 0.1739 - val_accuracy: 0.9501
# Epoch 12/20
# 73/73 [==============================] - 46s 626ms/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.1561 - val_accuracy: 0.9518
# Epoch 13/20
# 73/73 [==============================] - 46s 627ms/step - loss: 0.0258 - accuracy: 0.9923 - val_loss: 0.1495 - val_accuracy: 0.9466
# Epoch 14/20
# 73/73 [==============================] - 45s 622ms/step - loss: 0.0218 - accuracy: 0.9923 - val_loss: 0.1660 - val_accuracy: 0.9518
# Epoch 15/20
# 73/73 [==============================] - 46s 630ms/step - loss: 0.0181 - accuracy: 0.9935 - val_loss: 0.1595 - val_accuracy: 0.9535
# Epoch 16/20
# 73/73 [==============================] - 45s 619ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.1553 - val_accuracy: 0.9552
# Epoch 17/20
# 73/73 [==============================] - 45s 620ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.1779 - val_accuracy: 0.9587
# Epoch 18/20
# 73/73 [==============================] - 45s 614ms/step - loss: 0.0316 - accuracy: 0.9901 - val_loss: 0.1739 - val_accuracy: 0.9484

# %%
#evaluate model
model.evaluate(test_data)
# Out:
# 19/19 [==============================] - 5s 264ms/step - loss: 0.1739 - accuracy: 0.9484
# [0.1738545149564743, 0.9483649134635925]

# %%
#plotting training values
sns.set()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

#accuracy plot
plt.plot(epochs, acc, color='green', label='Training Accuracy')
plt.plot(epochs, val_acc, color='blue', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.figure()
#loss plot
plt.plot(epochs, loss, color='pink', label='Training Loss')
plt.plot(epochs, val_loss, color='red', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
#train data accuracy and loss
plt.plot(history.history['val_loss'], label = 'training loss')
plt.plot(history.history['val_accuracy'], label = 'training accuracy')
plt.legend()

# %%
#test data accuracy and loss
plt.plot(history.history['loss'], label = 'training loss')
plt.plot(history.history['accuracy'], label = 'training accuracy')
plt.legend()

# %%
#example 1
image_path = "../input/covid19-radiography-database/COVID-19 Radiography Database/COVID-19/COVID-19 (104).png"
new_img = image.load_img(image_path, target_size=(244, 244))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
prediction = model.predict(img)
prediction = np.argmax(prediction,axis=1)
print(prediction)
print(class_names[prediction[0]])
plt.imshow(new_img)
# Out:
# [0]
# COVID-19

# %%
#example 2
image_path = "../input/covid19-radiography-database/COVID-19 Radiography Database/NORMAL/NORMAL (1002).png"
new_img = image.load_img(image_path, target_size=(244, 244))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
prediction = model.predict(img)
prediction = np.argmax(prediction,axis=1)
print(prediction)
print(class_names[prediction[0]])
plt.imshow(new_img)
# Out:
# [1]
# NORMAL

# %%
#example 3
image_path = "../input/covid19-radiography-database/COVID-19 Radiography Database/Viral Pneumonia/Viral Pneumonia (1002).png"
new_img = image.load_img(image_path, target_size=(244, 244))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
prediction = model.predict(img)
prediction = np.argmax(prediction,axis=1)
print(prediction)
print(class_names[prediction[0]])
plt.imshow(new_img)
# Out:
# [2]
# Viral Pneumonia

# %%
#save file as h5 model
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5

model.save("model.h5")
